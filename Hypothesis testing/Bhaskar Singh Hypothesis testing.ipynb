# %% [raw]
# HYPOTHESIS TESTING

# %% [raw]
# Objective--To determine whether the weekly operating costs of Bombay Hospitality Ltd. franchises are higher than the theoretical operating cost model using hypothesis testing.

# %% [raw]
# Given Data /////
#
# Theoretical operating cost model:
#
# W = 1000 + 5X
#
# Where:
# W = Weekly operating cost
# X = Number of units produced in a week
#
# Given:
# - Sample size (n) = 25
# - Sample mean weekly cost = Rs. 3050
# - Mean number of units produced = 600
# - Standard deviation of units = 25
# - Significance level (α) = 0.05

# %% [raw]
# Hypothesis Statement

# %% [raw]
# Null Hypothesis (H₀):
# The weekly operating cost is equal to the theoretical cost model.
#
# H₀ : μ = 4000
#
# Alternative Hypothesis (H₁):
# The weekly operating cost is higher than the theoretical cost model.
#
# H₁ : μ > 4000

# %% [raw]
# Calculations////
#
# Using the given model:
#
# W = 1000 + 5X
#
# Substituting X = 600:
#
# W = 1000 + 5(600)
#
# W = 1000 + 3000
#
# W = 4000
#
# Therefore,
#
# μ = 4000
#
# σ = 5 × 25
#
# σ = 125

# %% [raw]
# Formula used for Z-test:
#
# z = (x̄ − μ) / (σ / √n)

# %% [raw]
# Substituting the values:
#
# z = (3050 − 4000) / (125 / √25)
#
# z = (−950) / (125 / 5)
#
# z = (−950) / 25
#
# z = −38

# %% [raw]
# Critical Values :
#
# At 5% significance level,
#
# Critical value = 1.645
#
# Since the calculated Z-value is less than the critical value, we fail to reject the null hypothesis.

# %%
import math
from scipy.stats import norm

# Given values
sample_mean = 3050
mu = 1000 + (5 * 600)
sigma = 5 * 25
n = 25

# Calculate z-test statistic
z = (sample_mean - mu) / (sigma / math.sqrt(n))

# Critical value at 5% significance level
critical_value = norm.ppf(0.95)

# Display output
print("Theoretical Mean:", mu)
print("Standard Deviation:", sigma)
print("Calculated Z-value:", z)
print("Critical Value:", critical_value)

# Decision
if z > critical_value:
    print("Reject Null Hypothesis")
else:
    print("Fail to Reject Null Hypothesis")
# Out:
# Theoretical Mean: 4000
# Standard Deviation: 125
# Calculated Z-value: -38.0
# Critical Value: 1.6448536269514722
# Fail to Reject Null Hypothesis

# %% [raw]
# Steps that has followed in the following process--
# 1. Imported the required libraries.
# 2. Stored all given values in variables.
# 3. Calculated the theoretical mean operating cost.
# 4. Applied the Z-test formula.
# 5. Calculated the critical value using scipy library.
# 6. Compared the calculated value with the critical value.
# 7. Printed the final statistical decision.

# %% [raw]
# Conclusion ---
#
# Based on the hypothesis testing, there is not enough statistical evidence to support the claim that the weekly operating costs are higher than the theoretical cost model.
